# %%
#Install libraries
# !pip install --upgrade google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client
# Out:
# Requirement already satisfied: google-auth in /opt/anaconda3/lib/python3.12/site-packages (2.37.0)
# Requirement already satisfied: google-auth-oauthlib in /opt/anaconda3/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: google-auth-httplib2 in /opt/anaconda3/lib/python3.12/site-packages (0.2.0)
# Requirement already satisfied: google-api-python-client in /opt/anaconda3/lib/python3.12/site-packages (2.155.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2>=0.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-python-client) (2.24.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.25.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.8.30)

# %%
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from email.utils import parsedate_tz, mktime_tz
from datetime import datetime, timedelta
import base64
import os
import re
import csv


# Define the scope for the Gmail API
SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

# %%
# 2 options to authenticate. 
# Authenticate and create the Gmail API service
def authenticate_gmail():
    creds = None
    # Check if token.json exists for previous authentication sessions
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    
    # If no valid credentials, perform the OAuth flow
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for future use
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    service = build('gmail', 'v1', credentials=creds)
    return service

# Authenticate with an access token
def authenticate_gmail_with_access_token(access_token):
    creds = Credentials(token=access_token)
    service = build('gmail', 'v1', credentials=creds)
    return service

# %%
# Search Gmail for emails containing specific keywords
def search_emails(service, keywords_or1, keywords_or2, yearsago):  
    # Calculate the date 5 years ago
    five_years_ago = datetime.now() - timedelta(days=yearsago*365) 
    five_years_ago_str = five_years_ago.strftime('%Y/%m/%d')

    # Combine the first list of keywords with OR
    query1 = '(' + ' OR '.join(keywords_or1) + ')' if keywords_or1 else ''
    # Combine the second list of keywords with OR
    query2 = '(' + ' OR '.join(keywords_or2) + ')' if keywords_or2 else ''
    
    # Combine the two queries with AND and add the 'after' filter for emails received in the last 5 years
    query = f'{query1} AND {query2} AND after:{five_years_ago_str}'  #if query1 and query2 else f'{query1} AND after:{five_years_ago_str}' or f'{query2} AND after:{five_years_ago_str}'
 
    messages = []
    page_token = None


    while True:
        # Request a page of messages
        results = service.users().messages().list(
            userId='me',
            q=query,
            pageToken=page_token,
            maxResults=500  # Gmail API maxes at 500, adjust if needed
        ).execute()
        
        # Add the messages from this page to the results
        messages.extend(results.get('messages', []))

        # Check if there's another page
        page_token = results.get('nextPageToken')
        if not page_token:
            break
    # Debug
    print(f"Query used for search: {query}")
    print(f"Page Token: {page_token}")
    print(f"Messages retrieved so far: {len(messages)}")

    return messages  # Return the accumulated messages

# %%
# Get the subject, body, sender address, and date of an email
def get_email_details(service, message_id):
    message = service.users().messages().get(userId='me', id=message_id, format='full').execute()
    payload = message.get('payload', {})
    headers = payload.get('headers', [])

    # Extract the subject
    subject = next((header['value'] for header in headers if header['name'].lower() == 'subject'), "")

    # Extract the sender address
    sender = next((header['value'] for header in headers if header['name'].lower() == 'from'), "")

    # Extract the date
    date_str = next((header['value'] for header in headers if header['name'].lower() == 'date'), "")
    date = ""
    if date_str:
        date_tuple = parsedate_tz(date_str)
        if date_tuple:
            timestamp = mktime_tz(date_tuple)
            date = datetime.fromtimestamp(timestamp).strftime('%m/%d/%Y')  # Convert to MM/DD/YYYY format

    # Extract the body
    parts = payload.get('parts', [])
    body = ""
    if 'data' in payload.get('body', {}):
        body += base64.urlsafe_b64decode(payload['body']['data']).decode('utf-8')
    for part in parts:
        if part.get('mimeType') == 'text/plain':
            body += base64.urlsafe_b64decode(part['body']['data']).decode('utf-8')
        elif part.get('mimeType') == 'text/html':
            body += base64.urlsafe_b64decode(part['body']['data']).decode('utf-8')

    return subject.strip(), body.strip(), sender.strip(), date

# %%
# Extract dates and countries from the email body
def extract_dates_from_body(body):
    date_pattern = r'\b(?:\d{1,2}/\d{1,2}/\d{2,4}|\d{4}-\d{2}-\d{2}|\d{1,2} \w+ \d{4})\b'
    dates = re.findall(date_pattern, body)
    return dates

def extract_countries_from_body(body):
    country_pattern = r'\b(?:Afghanistan|Albania|Algeria|Andorra|Angola|Argentina|Armenia|Australia|Austria|Azerbaijan|Bahamas|Bahrain|Bangladesh|Barbados|Belarus|Belgium|Belize|Benin|Bhutan|Bolivia|Botswana|Brazil|Brunei|Bulgaria|Burundi|Cambodia|Cameroon|Canada|Chad|Chile|China|Colombia|Comoros|Congo|Croatia|Cuba|Cyprus|Czech Republic|Denmark|Djibouti|Dominica|Ecuador|Egypt|El Salvador|Estonia|Eswatini|Ethiopia|Fiji|Finland|France|Gabon|Gambia|Georgia|Germany|Ghana|Greece|Grenada|Guatemala|Guinea|Guyana|Haiti|Honduras|Hungary|Iceland|India|Indonesia|Iran|Iraq|Ireland|Israel|Italy|Jamaica|Japan|Jordan|Kazakhstan|Kenya|Kiribati|Kuwait|Kyrgyzstan|Laos|Latvia|Lebanon|Lesotho|Liberia|Libya|Liechtenstein|Lithuania|Luxembourg|Madagascar|Malawi|Malaysia|Maldives|Mali|Malta|Mauritania|Mauritius|Mexico|Micronesia|Moldova|Monaco|Mongolia|Montenegro|Morocco|Mozambique|Myanmar|Namibia|Nauru|Nepal|Netherlands|New Zealand|Nicaragua|Niger|Nigeria|Norway|Oman|Pakistan|Palau|Panama|Paraguay|Peru|Philippines|Poland|Portugal|Qatar|Romania|Russia|Rwanda|Samoa|San Marino|Saudi Arabia|Senegal|Serbia|Seychelles|Singapore|Slovakia|Slovenia|Somalia|South Africa|Spain|Sri Lanka|Sudan|Suriname|Sweden|Switzerland|Syria|Taiwan|Tajikistan|Tanzania|Thailand|Togo|Tonga|Tunisia|Turkey|Turkmenistan|Tuvalu|Uganda|Ukraine|United Arab Emirates|United Kingdom|United States|Uruguay|Uzbekistan|Vanuatu|Vatican|Venezuela|Vietnam|Yemen|Zambia|Zimbabwe)\b'
    countries = re.findall(country_pattern, body, re.IGNORECASE)
    return list(set(countries))

def extract_airport_codes_from_body(body):
    # Regex for 3-letter IATA airport codes (assumes they are all uppercase letters)
    airport_pattern = r'\b[A-Z]{3}\b'
    # Find all matching codes
    airport_codes = re.findall(airport_pattern, body)
    
    # Common filtering step to avoid false positives
    # If desired, compare the codes with a list of valid IATA codes for stricter accuracy
    return list(set(airport_codes))

# %%
def main():
    access_token = "ya29.a0ARW5m76332xlvBB-HUiJ2mc10B7QEVqzipxeJiSp3xejOKQevaHf-XT_YTg2BHtfgKsTUuQCUJMYL_VkpBmWIw39ypfr6ntAd29GN4gY48iNsccJO7m8SIkNzKbUmcAuHsd3VaBEqYWng61VuawIb3uL_EblQybwKNC7x23UMAaCgYKAYgSARISFQHGX2MiPxIGQ6zZMWk5AYBqGPeq_A0177" #EDIT HERE access token if using this method
    keywords_or1 = ["flight", "trip", "booking"]  # EDIT HERE: Replace with your keywords
    keywords_or2 = ["itinerary", "reservation", "confirmation", "confirmed","departure"] # EDIT HERE: Replace with your keywords
    yearsago = 5 # EDIT HERE time range as an integer (X years ago)
    
    service = authenticate_gmail_with_access_token(access_token)  # EDIT HERE to change authentication method
    messages = search_emails(service, keywords_or1, keywords_or2, yearsago) 

    if not messages:
        print("No messages found.")
    else:
        print(f"Found {len(messages)} messages:\n")
        
        # Open a CSV file for writing
        with open("email_output.csv", "w", newline="", encoding="utf-8") as csvfile:
            # Define CSV writer and header
            csvwriter = csv.writer(csvfile)
            csvwriter.writerow(["Email ID", "Subject", "Sender", "Date", "Dates in Body", "Countries in Body", "Airport Codes"])

            for msg in messages:
                msg_id = msg['id']
                subject, email_body, sender, date = get_email_details(service, msg_id)

                # Filter emails strictly based on `keywords_or1` in the subject
                if any(keyword.lower() in subject.lower() for keyword in keywords_or1):
                    dates = extract_dates_from_body(email_body)
                    countries = extract_countries_from_body(email_body)
                    airport_codes = extract_airport_codes_from_body(email_body)

                    if dates:
                        # Write data to CSV
                        csvwriter.writerow([
                            msg_id,
                            subject.strip(),
                            sender.strip(),
                            date.strip(),
                            ", ".join(dates),  # Dates as a single string
                            ", ".join(countries) if countries else "None",  # Countries as a single string
                            ", ".join(airport_codes) if airport_codes else "None"  # Airport codes as a single string
                        ])
                        print(f"Email ID: {msg_id}\nSubject: {subject}\nSender: {sender}\nDate: {date}\nDates in Body: {', '.join(dates)}\nCountries in Body: {', '.join(countries) if countries else 'None'}\n{'-'*50}\n")
                    else:
                        print(f"Email ID: {msg_id} skipped as it doesn't contain dates in the body.\n")
                else:
                    print(f"Email ID: {msg_id} skipped as it doesn't match 'keywords_or1' in subject.\n")

    print("Output saved to email_output.csv.")

if __name__ == '__main__':
    main()
# Out:
# Found 1114 messages:
#
# Email ID: 193d0f9359df7341 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193d03cd32d95d0c skipped as it doesn't contain dates in the body.
#
# Email ID: 193cb581fd550915 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193ca565dfff5267 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193bd9bc6407f642 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193b1d55521a2053 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193ac41169b924fb skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1939bde4582e1c4b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1939a4d901533ed1 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193953ed44bf13b4 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193953b4864385bb skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1939311b3a7e43b9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193924d4f69b14a1 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19388718f4595239 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1938866307cc1bda skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1937ec08cafd48b5 skipped as it doesn't contain dates in the body.
#
# Email ID: 19378d75e88e5857 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1937852b0c716be9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1936f6ea1873df83 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1936e7218b1ea7fa skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19369d9909952b46 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193697a77acddc3d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193648d4320a2fa0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1935f1f5b0d8e0a5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1935f0ca94b933ee skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193599d620128897 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19354ce0ed73648c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1934f6a0bca8cb03 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1934661d70591b64 skipped as it doesn't contain dates in the body.
#
# Email ID: 193408861a949a49 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193228656c63f37c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1932155b0260d8ce skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1931c26468579357 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19311a44a0ca55fd skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19303eb4fdb95f38
# Subject: Your Flight Confirmation Code Y8YMRB
# Sender: Frontier Airlines <flights@emails.flyfrontier.com>
# Date: 11/06/2024
# Dates in Body: 11/15/22, 11/15/22, 1/01/2025, 1/01/2025, 1/08/2025, 1/09/2025, 2/7/23
# Countries in Body: United States
# --------------------------------------------------
#
# Email ID: 193033da40dc0bec skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 193023a33a27da86
# Subject: Important information about your upcoming flight. Confirmation Code Y8YMRB
# Sender: Frontier Airlines <info@reservation.flyfrontier.com>
# Date: 11/06/2024
# Dates in Body: 11/06/24
# Countries in Body: None
# --------------------------------------------------
#
# Email ID: 192f4dd72c2d34d2 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192f4da42860d67f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192ef52600960c6b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192ef5133d78d974 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192ef474a5ab1189 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192e8668d81ebd23 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192caf33039494d9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192ca47cdf08b1c0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192bb88a2451a4f9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192b6423a18092dc skipped as it doesn't contain dates in the body.
#
# Email ID: 192af73ef134ad57 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192a57188663bcd6 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1929ac604e332e68 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1929644482863726
# Subject: Your Flight Confirmation Code Y8YMRB
# Sender: Frontier Airlines <flights@emails.flyfrontier.com>
# Date: 10/16/2024
# Dates in Body: 11/15/22, 11/15/22, 1/01/2025, 1/01/2025, 1/08/2025, 1/09/2025, 2/7/23
# Countries in Body: United States
# --------------------------------------------------
#
# Email ID: 19295b4f60446f68
# Subject: Important information about your upcoming flight. Confirmation Code Y8YMRB
# Sender: Frontier Airlines <info@reservation.flyfrontier.com>
# Date: 10/16/2024
# Dates in Body: 10/16/24
# Countries in Body: None
# --------------------------------------------------
#
# Email ID: 19286717bca33aaa skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19281918ccb7b48d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1928104c9c35a4ca skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19280fdd0e6b3ef7 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1927847a8891651e skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19276c7c458fd622 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192753b6d746bf74 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1926de9aa33e5fb5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1926d281f8157718 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19262cea58a6068d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19262497130a6837 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192598a1d75786dd skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1925957100a6e0f5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1925843e53c70791 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19253fd1dda43d50 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1924f835be53e07c
# Subject: Your Flight Confirmation Code Y8YMRB
# Sender: Frontier Airlines <flights@emails.flyfrontier.com>
# Date: 10/02/2024
# Dates in Body: 11/15/22, 11/15/22, 1/01/2025, 1/01/2025, 1/08/2025, 1/09/2025, 2/7/23
# Countries in Body: United States
# --------------------------------------------------
#
# Email ID: 1924f7df9cc911f5
# Subject: Your Flight Confirmation Code Y8YMRB
# Sender: Frontier Airlines <flights@emails.flyfrontier.com>
# Date: 10/02/2024
# Dates in Body: 11/15/22, 11/15/22, 1/01/2025, 1/01/2025, 1/08/2025, 1/09/2025, 2/7/23
# Countries in Body: United States
# --------------------------------------------------
#
# Email ID: 1923740f1b2ce0e6
# Subject: Booking confirmed in Budapest for 2024-09-28 at 15:00
# Sender: GuruWalk <no-reply@guruwalk.com>
# Date: 09/28/2024
# Dates in Body: 2024-09-28, 2024-09-28, 2024-09-28, 28/09/2024, 2024-09-28, 2024-09-28, 2024-09-28, 2024-09-28, 2024-09-28, 28/09/2024, 2024-09-28, 2024-09-28
# Countries in Body: Hungary, Spain, hungary
# --------------------------------------------------
#
# Email ID: 1922ed2f952d1900 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1922ed2cbc3cfa2e
# Subject: ÖBB booking – 0849 2340 5422 6406 – Sep 27 2024
# Sender: tickets@oebb.at
# Date: 09/26/2024
# Dates in Body: 26 Sep 2024, 43 5 1717, 26 Sep 2024, 43 5 1717
# Countries in Body: None
# --------------------------------------------------
#
# Email ID: 19225627c459ec8f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1922552eb73f733d skipped as it doesn't contain dates in the body.
#
# Email ID: 19222b3716aa2d91 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1922141dc8b9ce3c skipped as it doesn't contain dates in the body.
#
# Email ID: 1922110657b3b458 skipped as it doesn't contain dates in the body.
#
# Email ID: 1922038769eacab1
# Subject: Departure from gate G16 | Your flight to Belgrade
# Sender: Austrian Airlines Flight Change <flight.change@information.austrian.com>
# Date: 09/23/2024
# Dates in Body: 23 September 2024
# Countries in Body: Austria
# --------------------------------------------------
#
# Email ID: 1921ba44fc012e1e skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19218e998dac11bb
# Subject: Booking details | Departure: 23 September 2024 | VIE-BEG
# Sender: "lufthansa.com" <online@booking.lufthansa.com>
# Date: 09/22/2024
# Dates in Body: 23 September 2024, 27 September 2024, 23 September 2024, 27 September 2024, 22 September 2024
# Countries in Body: None
# --------------------------------------------------
#
# Email ID: 19218e30abfdc815 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19214cb5757bb4c8 skipped as it doesn't contain dates in the body.
#
# Email ID: 19214cb4b0ba4355 skipped as it doesn't contain dates in the body.
#
# Email ID: 192119c7bc39cc3d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192112855f4c283d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19211155bd3bca2b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1920bc0a9ad7ecbb skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1920b3c092f3596e skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1920aee84ac93038 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19206bb9d2840e7d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 192009c9e1820313 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 191f057a64f5db3f skipped as it doesn't contain dates in the body.
#
# Email ID: 191e7122f9309b46 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 191e6e97aac598d1 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 191e61b42779b640 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 191dc99cf66288c2 skipped as it doesn't contain dates in the body.
#
# Email ID: 191d7bfd038426d5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 191d2177dda3b983 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 191c3de8f5c4f14f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 191c306fcaaeb791 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19194e42598dcd86 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19193cd532212dcc skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1918b903139b85c3 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19180af3eabc9e19
# Subject: Get more perks for booking for others
# Sender: IHG One Rewards <IHGOneRewards@mc.ihg.com>
# Date: 08/23/2024
# Dates in Body: 8/23/2024
# Countries in Body: Georgia, Cuba
# --------------------------------------------------
#
# Email ID: 1917fc5435b77b49 skipped as it doesn't contain dates in the body.
#
# Email ID: 191753e1953f1d33 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1914c4aeae8ccc1c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19137702a31941e7 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1912dc3b4156a7e2
# Subject: Kimberlee, save big on your next trip
# Sender: IHG One Rewards <IHGOneRewards@mc.ihg.com>
# Date: 08/07/2024
# Dates in Body: 8/29/24, 8/29/24, 8/7/2024, 8/29/24, 8/29/24
# Countries in Body: Georgia, Cuba
# --------------------------------------------------
#
# Email ID: 191286c4b0c7543f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1912868a079ee04d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190fa87e3f613b7b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190efcbbb3d8d3b0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190ec3a38f584719 skipped as it doesn't contain dates in the body.
#
# Email ID: 190e575e9bd1d908 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190e232dab6a9984 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190e113673a6aeda skipped as it doesn't contain dates in the body.
#
# Email ID: 190e0498639b04eb skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190e0059a6980d6c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190df79a882f4bba skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190dcb60bb5e6dd4 skipped as it doesn't contain dates in the body.
#
# Email ID: 190dc7d6dbf358f2 skipped as it doesn't contain dates in the body.
#
# Email ID: 190dc69a1acdb718 skipped as it doesn't contain dates in the body.
#
# Email ID: 190dc639a46760d4 skipped as it doesn't contain dates in the body.
#
# Email ID: 190dc48c5cd0e488 skipped as it doesn't contain dates in the body.
#
# Email ID: 190dbd2292e05106 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190dbc0718c0f365 skipped as it doesn't contain dates in the body.
#
# Email ID: 190dbb1b22115505 skipped as it doesn't contain dates in the body.
#
# Email ID: 190db98487f46d4f skipped as it doesn't contain dates in the body.
#
# Email ID: 190d75327c232fc3 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190cb02b5990b640 skipped as it doesn't contain dates in the body.
#
# Email ID: 190ca3b898cafc03 skipped as it doesn't contain dates in the body.
#
# Email ID: 190c5fff4a82adc9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190c5bfb640aeab1 skipped as it doesn't contain dates in the body.
#
# Email ID: 190bd98859a1543c skipped as it doesn't contain dates in the body.
#
# Email ID: 190bc1093859bfb8 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190b94760a735e75 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190b748dee3f118c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190b199de7c34fd4 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190acb54f4423221 skipped as it doesn't contain dates in the body.
#
# Email ID: 190aa85c7b237507 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1909e36ed536f177 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1909b1725f409fe2 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1909849f1337bc79 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1909802c9143c9a8 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190839634e67df14 skipped as it doesn't contain dates in the body.
#
# Email ID: 19074fdf5e365458 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 190744972be415c9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1905507fa0588532 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 19054f3becf4461e skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1905034626c8193d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1904c6546c03dc76 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1904c5ca272e6463 skipped as it doesn't contain dates in the body.
#
# Email ID: 1903f9f123a1d44b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1903b8a8f54a679c skipped as it doesn't contain dates in the body.
#
# Email ID: 190365b9d67a779a skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1900e1831b1a165d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ff40270dde93b1 skipped as it doesn't contain dates in the body.
#
# Email ID: 18fee38153dd7af9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18fe95aaaa6c7435 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18fe88d0934c9c19 skipped as it doesn't contain dates in the body.
#
# Email ID: 18fe35684e7248ae skipped as it doesn't contain dates in the body.
#
# Email ID: 18fc465e35f03b65 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18fa74339e941852 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18fa622f191edae3 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18f919fe7cfe72ec skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18f8824d36a9270b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18f821a8c8cc17b9
# Subject: Put a luxurious trip to Las Vegas on your list ✨
# Sender: IHG One Rewards <IHGOneRewards@mc.ihg.com>
# Date: 05/16/2024
# Dates in Body: 5/16/2024
# Countries in Body: Georgia, Cuba
# --------------------------------------------------
#
# Email ID: 18f79cbf52321e76 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18f79c6214739f18 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18f79c613e8f1a77 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18f62d5d3e68e4c0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18f2553be76c51f7 skipped as it doesn't contain dates in the body.
#
# Email ID: 18f2539652a1a96d skipped as it doesn't contain dates in the body.
#
# Email ID: 18f1611fe8d9f848 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18f0b8c5e6b08653 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ef790423d3964b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ef62088592e8e9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ef2749e2fb9db2 skipped as it doesn't contain dates in the body.
#
# Email ID: 18ef240953b34c35 skipped as it doesn't contain dates in the body.
#
# Email ID: 18ef233586d8b84a skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ef1a6b7ecb2dd8 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ec823ac6ff1371 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ec4782be2d6bb6 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ebb7c2a5153b89 skipped as it doesn't contain dates in the body.
#
# Email ID: 18ebb735dc539caf skipped as it doesn't contain dates in the body.
#
# Email ID: 18ebb23c787fd9dd skipped as it doesn't contain dates in the body.
#
# Email ID: 18ebb0b97bcce4b9 skipped as it doesn't contain dates in the body.
#
# Email ID: 18ebaf8e9a152453 skipped as it doesn't contain dates in the body.
#
# Email ID: 18eba1b2c614dcb8 skipped as it doesn't contain dates in the body.
#
# Email ID: 18eb62d7a2a233cd
# Subject: Check in for your flight to Los Angeles.
# Sender: JetBlue Reservations <jetblueairways@email.jetblue.com>
# Date: 04/06/2024
# Dates in Body: 2/25/21, 7/20/21
# Countries in Body: United States
# --------------------------------------------------
#
# Email ID: 18eb10731c4f6e7d skipped as it doesn't contain dates in the body.
#
# Email ID: 18eabe0b496711d0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18eaba81c7f2597b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18eab15677dbf1b4 skipped as it doesn't contain dates in the body.
#
# Email ID: 18ea9db2e34fff4b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ea3a1dd9f90819 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ea0b07d9ba2bed skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e8ca063098846c skipped as it doesn't contain dates in the body.
#
# Email ID: 18e8c9f9260cd47c
# Subject: JetBlue booking confirmation for KIMBERLEE  CHANG - KDFBLO
# Sender: JetBlue Reservations <jetblueairways@email.jetblue.com>
# Date: 03/29/2024
# Dates in Body: 2/25/21, 7/20/21
# Countries in Body: United States, Mexico
# --------------------------------------------------
#
# Email ID: 18e86cf094226960 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e85b584ec8b133 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e724e76363f575 skipped as it doesn't contain dates in the body.
#
# Email ID: 18e63df2c1af48e5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e5bf391f106abd skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e525f4cde89b28 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e4d48d7a5d70ba skipped as it doesn't contain dates in the body.
#
# Email ID: 18e4d01a8a711cf8 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e438dc290b051b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e3e988f0720723 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e33cd67af7c855 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e301b035d83af1 skipped as it doesn't contain dates in the body.
#
# Email ID: 18e2f474e4e688e8 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e2ea37d1f12e42 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e27edb55ec6f60
# Subject: Need-to-knows for your trip to Port of Spain.
# Sender: JetBlue <jetblueairways@email.jetblue.com>
# Date: 03/10/2024
# Dates in Body: 2/25/21, 7/20/21
# Countries in Body: United States, Spain
# --------------------------------------------------
#
# Email ID: 18e1e996942208f4 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e19569f71562f5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18e0f88ad6e220a3 skipped as it doesn't contain dates in the body.
#
# Email ID: 18df8c55c8c38fba skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18df0e335b2a4ba1 skipped as it doesn't contain dates in the body.
#
# Email ID: 18deb745f590d2da skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18deb5ce7c5729ba skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18de626a9f70bb80 skipped as it doesn't contain dates in the body.
#
# Email ID: 18de1047f5c1195b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18de0ae272644466 skipped as it doesn't contain dates in the body.
#
# Email ID: 18ddcdab0240efc1 skipped as it doesn't contain dates in the body.
#
# Email ID: 18dd95d874d1e492 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18dd73c163aa99ed skipped as it doesn't contain dates in the body.
#
# Email ID: 18dd65e6ad7961df skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18dd2c5f5ef9e07c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18dd2af0fe6557ad skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18dcd6ac7a3943ce skipped as it doesn't contain dates in the body.
#
# Email ID: 18dc914b1358f589 skipped as it doesn't contain dates in the body.
#
# Email ID: 18dc654def2d6438 skipped as it doesn't contain dates in the body.
#
# Email ID: 18dc22f71a6f028c skipped as it doesn't contain dates in the body.
#
# Email ID: 18dc20f017995b9f skipped as it doesn't contain dates in the body.
#
# Email ID: 18daf6c3c1d8d289 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18daa6cda2d6ab77 skipped as it doesn't contain dates in the body.
#
# Email ID: 18d7b3a83e000214 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d7b3a4a0534f02
# Subject: JetBlue booking confirmation for KIMBERLEE  CHANG - ETQVOJ
# Sender: JetBlue Reservations <jetblueairways@email.jetblue.com>
# Date: 02/05/2024
# Dates in Body: 2/25/21, 7/20/21
# Countries in Body: United States, Mexico, Spain
# --------------------------------------------------
#
# Email ID: 18d7b265c1e50faf skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d68707b5eb43b5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d65ce469678581 skipped as it doesn't contain dates in the body.
#
# Email ID: 18d5c8779899eb84 skipped as it doesn't contain dates in the body.
#
# Email ID: 18d47ba4953130fc skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d2cc913137539b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d28b22d2fabf57 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d24011d7108084
# Subject: JetBlue booking confirmation for KIMBERLEE  CHANG - YYSHJD
# Sender: JetBlue Reservations <jetblueairways@email.jetblue.com>
# Date: 01/19/2024
# Dates in Body: 2/25/21, 7/20/21
# Countries in Body: United States, Mexico
# --------------------------------------------------
#
# Email ID: 18d202cecd9c4f63 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d1dbf7b1fb7a9b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d17f2777ad28ec skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d129858bbd3449 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d0a6da8457ce02 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d07b0a8f63b018 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18d060ffbcde7813 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18cf698850b9b7dc skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ce8d5d2870f9f4 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ce19555e907c46 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18cdc11dedac5dd9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18cd5c2af4130258 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18cd571d2c224e97 skipped as it doesn't contain dates in the body.
#
# Email ID: 18cd2107b05be9bc skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18cc1284b2aae03c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18cbf2c5c56addef skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18cae6fa3347a053 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18cad89a3fcb6ae6 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18c8ed27db8c3b1b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18c89e35ee1a16fc skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18c89d91af48150a skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18c82ab750fe35e5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18c7f5f764a7cf33 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18c79b1af424460c skipped as it doesn't contain dates in the body.
#
# Email ID: 18c6a585a273680e skipped as it doesn't contain dates in the body.
#
# Email ID: 18c41a929aff7c2c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18c3b3fbe2d0ae22 skipped as it doesn't contain dates in the body.
#
# Email ID: 18c1dfa6f833d3e6 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18c1bcdc44a3e550 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18c17c38e1c81e3f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18bf8e8255a56a2d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18bf7b914ca28ef0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18bd63963bb9a5d0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18bc62ac1d5978c6 skipped as it doesn't contain dates in the body.
#
# Email ID: 18bc5c933ed7233e skipped as it doesn't contain dates in the body.
#
# Email ID: 18bc5c580140f76f skipped as it doesn't contain dates in the body.
#
# Email ID: 18bc5b284bf4be99 skipped as it doesn't contain dates in the body.
#
# Email ID: 18bc579a88f1e93e skipped as it doesn't contain dates in the body.
#
# Email ID: 18bc15df1289d390
# Subject: Check in for your flight to New York.
# Sender: JetBlue Reservations <jetblueairways@email.jetblue.com>
# Date: 11/11/2023
# Dates in Body: 2/25/21, 7/20/21
# Countries in Body: United States
# --------------------------------------------------
#
# Email ID: 18bc0ab0a6e0bec7 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18bbc37a001c6cb8
# Subject: What to expect on your flight to New York.
# Sender: JetBlue <jetblueairways@email.jetblue.com>
# Date: 11/10/2023
# Dates in Body: 12/31/23, 1/7/24
# Countries in Body: None
# --------------------------------------------------
#
# Email ID: 18bbb0b74ddd90f0 skipped as it doesn't contain dates in the body.
#
# Email ID: 18bba8c501e46f19 skipped as it doesn't contain dates in the body.
#
# Email ID: 18bb6876936c0610 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18bb652d4dcf118b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18bb630d2dd6fc47 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18bacc4b7dd34d63
# Subject: Need-to-knows for your trip to New York.
# Sender: JetBlue <jetblueairways@email.jetblue.com>
# Date: 11/07/2023
# Dates in Body: 2/25/21, 7/20/21
# Countries in Body: United States
# --------------------------------------------------
#
# Email ID: 18bab7fa7c8e1796 skipped as it doesn't contain dates in the body.
#
# Email ID: 18ba737d72210c30 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ba5239c4f50f32 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b9f0e5f10b6d08
# Subject: JetBlue booking confirmation for KIMBERLEE  CHANG - OCRCJD
# Sender: JetBlue Reservations <jetblueairways@email.jetblue.com>
# Date: 11/05/2023
# Dates in Body: 2/25/21, 7/20/21
# Countries in Body: United States, Mexico
# --------------------------------------------------
#
# Email ID: 18b9c1edcd3dfa7c
# Subject: Your trip confirmation-VRDUYB  10NOV
# Sender: American Airlines <no-reply@notify.email.aa.com>
# Date: 11/04/2023
# Dates in Body: 11/10/2023, 11/11/2023
# Countries in Body: Canada, canada
# --------------------------------------------------
#
# Email ID: 18b9c07651819682 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b952a0d72e32b6 skipped as it doesn't contain dates in the body.
#
# Email ID: 18b9243ed6ae3950 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b9057ca2c9652f skipped as it doesn't contain dates in the body.
#
# Email ID: 18b904b0833c31cd
# Subject: Trip Cancellation
# Sender: American Airlines <no-reply@info.email.aa.com>
# Date: 11/02/2023
# Dates in Body: 26 Sep 2004
# Countries in Body: None
# --------------------------------------------------
#
# Email ID: 18b8ec8a0fc7367e skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b834f45352cbc0 skipped as it doesn't contain dates in the body.
#
# Email ID: 18b80c8edccc0547 skipped as it doesn't contain dates in the body.
#
# Email ID: 18b7d4a03441c3a9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b774f3855f3b37 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b72d0d6b8be0c4 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b6e1ed9b700ae8 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b6d857223c023f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b68bde23174346 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b6740a8a553b00 skipped as it doesn't contain dates in the body.
#
# Email ID: 18b620df2c541efc skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b6203073005e55 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b5d0fbb8ebde80 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b5d05191ac7c3a skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b5cbcdd6509fd5 skipped as it doesn't contain dates in the body.
#
# Email ID: 18b5c93f2c4d04a3 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b5b1f83aaae26f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b5abbc7fbeab50 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b5ab90255714cf skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b5ab3c5aee63f7 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b59b07f9a67728 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b59acab77b879b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b57ee0d701c1d2 skipped as it doesn't contain dates in the body.
#
# Email ID: 18b57bf32ddf2a3a skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b57bf1ff30f91c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b57ba8572689e4 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b57ba82575bc20 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b545540b7159a5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b50f0ab2dbb6fb skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b3ab7dd4c8d543 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b39f6db39d6cdb skipped as it doesn't contain dates in the body.
#
# Email ID: 18b38cc0fc5d6db7 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b25d56a8a2298a skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b238d216f27242 skipped as it doesn't contain dates in the body.
#
# Email ID: 18b238d124aff16a skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b1efef8de26092 skipped as it doesn't contain dates in the body.
#
# Email ID: 18b162f09a732a03 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b0f91741c735db skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b0ed6a4b2b0ba8 skipped as it doesn't contain dates in the body.
#
# Email ID: 18b01b1bed06853d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18b01863514e54f2 skipped as it doesn't contain dates in the body.
#
# Email ID: 18b012fe20cb24f5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18af663f6a7c1385 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18af65b656eeb66b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18af65b375f6c4eb skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ae70e4d6f6e33f
# Subject: Booking confirmation | Viva Aerobus
# Sender: VivaAerobus No-Reply <reservations@vivaaerobus.com>
# Date: 09/30/2023
# Dates in Body: 25/09/1991, 12/12/1990
# Countries in Body: Mexico
# --------------------------------------------------
#
# Email ID: 18ad46694d3a8dad skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ac337ab48c6ca2 skipped as it doesn't contain dates in the body.
#
# Email ID: 18ab96f9ddf84301 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ab8189a700f0a1 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18ab359805ea30e3
# Subject: Booking confirmation | Viva Aerobus
# Sender: VivaAerobus No-Reply <reservations@vivaaerobus.com>
# Date: 09/20/2023
# Dates in Body: 25/09/1991, 12/12/1990
# Countries in Body: Mexico
# --------------------------------------------------
#
# Email ID: 18ab35076f5bd4a3 skipped as it doesn't contain dates in the body.
#
# Email ID: 18ab341c37846904
# Subject: Booking confirmation | Viva Aerobus
# Sender: VivaAerobus No-Reply <reservations@vivaaerobus.com>
# Date: 09/20/2023
# Dates in Body: 25/09/1991, 12/12/1990
# Countries in Body: Mexico
# --------------------------------------------------
#
# Email ID: 18a9b12b0452ac56 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18a95a4f42066bd2 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18a711e4d738b595 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18a24a07a356f39b skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18a1a3ac49c26191 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 189d390c24293c09 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 189d1a7491c8bcef skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 189c210be3f4a892 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 189bd6a7584055b0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 189b46397f4d19fb skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 189b1821863baf46 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18999425e232bd01 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 189992d1d55e97b9 skipped as it doesn't contain dates in the body.
#
# Email ID: 189986823966c777 skipped as it doesn't contain dates in the body.
#
# Email ID: 189937d3655633e6 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1898544837e4dcc2 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1896f1c18d96e966 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1896ac6b6a2ff2b0 skipped as it doesn't contain dates in the body.
#
# Email ID: 18950873be0af091 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18945e655a1b234f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 189371057ff723aa skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1892848e55d2ec1a skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1890e15702a698eb skipped as it doesn't contain dates in the body.
#
# Email ID: 1890e114c6b9967c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18908eef417bbebd skipped as it doesn't contain dates in the body.
#
# Email ID: 18903c87aee9e0f4 skipped as it doesn't contain dates in the body.
#
# Email ID: 188fe39e63af7365 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188c0a57d1fce0d0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188ac1fab504b413 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188831d85d574030 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188829afa0492166 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188803b8262def00 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1887d805535b1f07 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1887d5fe83b4db5c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1887d505fe5da583 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1887d39d598e9bd6 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188785625853db7a skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18878537cdcbd3a9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188783e73d450c59 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188783d9060646de skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18878189f2b081e8 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18878155323de6c3 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18878120d1a2c535 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1887811edbc6e947 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18877eff949894e0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188777d3b06a15cc skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18875d5a32b1e23f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18874d32c93fedde skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188733c8917eb107 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18872fa9c358c747 skipped as it doesn't contain dates in the body.
#
# Email ID: 1886dc566b20babe skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1886d856d6845853 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188683b9fa428f58 skipped as it doesn't contain dates in the body.
#
# Email ID: 18862f6cd4709bc6 skipped as it doesn't contain dates in the body.
#
# Email ID: 188574bca4b58e7e skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1884946fe5f4078d skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1884944b2ff90ef9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 18848ee1e2fc6083 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188419a7b89ce561 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 188306f1d47dc47f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 187e8059f22f7d7a skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 187dea41186486e1 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 187dea38992f5c23 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 187dea3613bf8d8a skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 187de5c986ad60a5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 187de5b9c4a394d3 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 187de5674be14375 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 187dc35c4c615c03 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID:
skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170e29c90ba28d92
# Subject: Advisory: Asia & the Pacific - Defer non-essential travel following pandemic declaration; implement on-approval-basis travel management framework for essential trips
# Sender: Security Alert - International SOS <riskinsights@internationalsos.com>
# Date: 03/16/2020
# Dates in Body: 16 Mar 2020, 65 6338 7800, 16 Mar 2020, 65 6338 7800
# Countries in Body: Guinea, Australia, Italy, Singapore, Philippines, Afghanistan, Palau, Tonga, Mongolia, France, Sri Lanka, Kiribati, Laos, India, Myanmar, Brunei, Pakistan, Vanuatu, Micronesia, Tuvalu, New Zealand, Japan, Spain, Samoa, Ireland, Thailand, Iran, Fiji, Bangladesh, Bhutan, Vietnam, Maldives, Malaysia, Nauru, Cambodia, Nepal, Indonesia, Taiwan, China
# --------------------------------------------------
#
# Email ID: 170d7be91f6de0a3 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170d3594f22386a0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170cfc7f565d5512 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170cf46a3f8fa5b8 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170ceb71f8fc2c39 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170c913241fa5686 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170bef172969605f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170b9b6d3a497c88 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170b6bf00e768523 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170b6beb0298a99f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170ab6800f926454 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170a6c8d33eeba6e skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170a3700580add84 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170a1bad377c0d15 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170a1ba9316ba08c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1709dae778ece180 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 17095ed81b8c17e8 skipped as it doesn't contain dates in the body.
#
# Email ID: 17090319bd9cc5ea skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1708fd77f67df8a3 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1708eec6880f6619 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 17086edf5150172f skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1708683df2931b37 skipped as it doesn't contain dates in the body.
#
# Email ID: 17083b277e404aeb skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 17081b8dd890ec6f skipped as it doesn't contain dates in the body.
#
# Email ID: 17081283d8dfb3d2 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1708055ac7b05265 skipped as it doesn't contain dates in the body.
#
# Email ID: 1707fe0c3d883c9b skipped as it doesn't contain dates in the body.
#
# Email ID: 1707e3df48f03e22 skipped as it doesn't contain dates in the body.
#
# Email ID: 1707cf8f59209357 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1707838e8a5b8b95 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170782c7e1d23075 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1707823cee70e748 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 17077d36d90fae7c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 17077d054f29b9bc skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 17076d62c3385672 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1707282cc9426445 skipped as it doesn't contain dates in the body.
#
# Email ID: 170673ebdecb0bdc skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1706534708f4d486 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170652f2d276f896 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 17063ae1f542ab11 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1706240399696488 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 17057f29c72f8e99 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 17052cb4478a21f3 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1703f15cf136b81e skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1703f085df07a9b7 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 17033e6323400ab0 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1702fa9cf1e94999 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 1702ebfccba4ef41 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 170240743a937337 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16ff0f1a60a40100 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16fedcd3aa17179c skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16fe7db8a412d749 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16fdc8afab817918 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16fd973d84316436 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16fd8e9b54c7afa6 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16fd8dcc3acdf206 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16fccee205813d41 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16fcbe678f1cbaa2 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16fc7beb090c9bef skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16fc2988c6189f77 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16fb1c5ce84d3f15 skipped as it doesn't contain dates in the body.
#
# Email ID: 16fadc9058fd8b6f skipped as it doesn't contain dates in the body.
#
# Email ID: 16fa46f9b9e8d26d skipped as it doesn't contain dates in the body.
#
# Email ID: 16f9f4fdc5bfb74f skipped as it doesn't contain dates in the body.
#
# Email ID: 16f9c2bec5ed8588 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16f8fb347f3aa2d2 skipped as it doesn't contain dates in the body.
#
# Email ID: 16f8b13891f276cb skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16f783ab89997ad5 skipped as it doesn't match 'keywords_or1' in subject.
#
# Email ID: 16f2236bc370bbf9 skipped as it doesn't match 'keywords_or1' in subject.
#
# Output saved to email_output.csv.
